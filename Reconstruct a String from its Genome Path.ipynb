# %%
def read_data_from(file_name):
    with open(file_name) as f:
        data = f.readlines()
    for i in range(0, len(data)):
        data[i] = data[i].strip()
    return data


def special_cocatination(kmers):
    answer = kmers[0]
    k = len(answer)
    for i in range(1, len(kmers)):
        answer += kmers[i][k - 1]

    print (answer)

if __name__ == "__main__":
    data = read_data_from("inrecon.txt")
    special_cocatination(data)
# Out:
# ...

# %% [markdown]
# Reference="https://github.com/andreyrozumnyi/rosalind/blob/master/Chapter%203/BA3B.py"

# %% [markdown]
# In this problem diffrent from previous, we select kmers based on intuition. Therefore the kmers that provided in the input file will be combine into one string. For example.
# ACCGA
#  CCGAA
#   CGAAG
#    GAAGC
#     AAGCT
#
# Final output =  ACCGAAGCT
